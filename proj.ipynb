# %%
def start_game():

    print('''           _       _                 _                                __ 
               / \   __| |_   _____ _ __ | |_ _   _ _ __ ___  ___    ___  / _|
              / _ \ / _` \ \ / / _ \ '_ \| __| | | | '__/ _ \/ __|  / _ \| |_ 
             / ___ \ (_| |\ V /  __/ | | | |_| |_| | | |  __/\__ \ | (_) |  _|
            /_/  _\_\__,_| \_/ \___|_| |_|\__|\__,_|_|  \___||___/  \___/|_|  
            | \ | | __ _ _ __ _ __ (_) __ _                                   
            |  \| |/ _` | '__| '_ \| |/ _` |                                  
            | |\  | (_| | |  | | | | | (_| |                                  
            |_| \_|\__,_|_|  |_| |_|_|\__,_|                               ''')
    print(' Welcome to the adventure of narnia!')
    print('You are in the land of narnia, where the sun dips into the horizon and paints the sky with hues of crimson and gold.')
    print('the villagers once a thriving community, have begun to vanish one by one')
    print('The village elder has called upon you to uncover the source ')

    while True:

        print('\nYou are in the Mysterious Forest.')
        print('What do you want to do?')
        print("1. Follow the winding path into the forest's depths")
        print("2. Investigate the ancient, gnarled tree with glowing runes")
        print("3. Search the underbrush for signs of recent disturbance")
        print('4. to exit game')

        choice = input('Enter choice: ')

        if choice == "1":
            print("You follow the winding path into the forest's depths.")
            print("You hear strange noises and feel like you're being watched.")
            print("You cautiously move forward to investigate the noise")
            print("As you round the bend you notice a hidden clearing up ahead")
            print("In the center of the clearing stands a massive stone monument covered in ancient runes")
            print('\n Choose What you want to do')
            print('1. Examine the monument closer')
            print('2. Return to main path')

            monument_choice = input('Enter choice: ')
            riddle_ans = 'key'
            riddle_guess = ''

            if monument_choice == "1":
                print('As you approach the monument, you notice a small, hidden compartment.')
                print('Inside, You find an ancient scroll bears a cryptic message')
                print('Solve riddle to read cryptic message')
                print(
                    'I am often sought, yet small in size, I can unlock doors, and open eyes. In pockets I am carried, or on chains I am worn, without me, many things would remain forlorn')
                while riddle_guess != riddle_ans:
                    riddle_guess = input('Enter guess: ')
                    if riddle_guess == riddle_ans:
                        addToInventory('Key')
                        print('Nice job! You unlocked a hidden key')
                        print('Return to the main path and continue your journey')
                        start_game()

                    else:
                        print('Try again')

        elif choice == "2":
            arrange_guess_word = ''
            arrange_word = 'sword'
            print("You investigate the ancient, gnarled tree with glowing runes.")
            print("You find a hidden compartment with a cryptic message.")
            print('Written in it is a D W S R O')
            print('Rearrange words to pick up weapon')
            while arrange_guess_word != arrange_word:
                arrange_guess_word = input('Word: ').lower()
                if arrange_guess_word == arrange_word:
                    addToInventory('Sword')
                    print('Nice job! You found the sword')
                else:
                    print('Try again')

        elif choice == "3":
            print("You search the underbrush for signs of recent disturbance.")
            print("You find a trail of footprints leading deeper into the forest.")
            print("Suddenly, you see a goblin")
            print('''@@@@@%%%%%%%%%%%%###%%###*####**++*+=-+===========+++++++=++++*#*++*+*******######%#%@@@@@@@@@@@@@@@
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@''')
            print('\nWhat do you want to do')
            print('1. fight the goblin')
            print('2. Run away')


            choice = input('Enter choice ')

            if choice == '1':
                #if player has a sword he can defeat goblin
                if 'Sword' in inventory:
                    print('You slayed the goblin with your sword')
                    break
                else:
                    print('You died')
                    break

            elif choice == '2':
                print("You escaped the goblin")

            else:
                print('invalid choice')

        elif choice == '4':
            print('Thanks for playing')
            break
        elif choice == '5':
            ancient_ruins()


def ancient_ruins():
    if 'key' and 'Sword' not in inventory:
        print('You need to defeat monster and have key to unlock this stage')
    else:
        print("\nYou are in the Ancient Ruins.")
        print("The air is thick with an otherworldly energy, and you can feel the weight of history bearing down upon you.")
        while True:
            print("\nWhat do you want to do?")
            print("1. Explore the grand temple, searching for the artifact")
            print("2. Quit")

            choice = input("Enter your choice: ")

            if choice == '1':
                print("You explore the grand temple, searching for the artifact.")
                print("You find the artifact, but it's guarded by a powerful entity.")
                print('solve mad lib to get artifact')

                adjective = 'majestic'
                noun = 'castle'
                verb = 'flapping'
                plural_noun = 'embers'
                adjective2 = 'brave'
                verb2 = 'unsheathe'
                verb3 = 'vanquish'

                mad_lib_words = ['majestic', 'castle', 'brave', 'vanquish', 'flapping', 'unsheathe', 'flapping']
                print(mad_lib_words)

                print(f"Yesterday, I saw a adjective")
                print(f"dragon flying over the  noun")
                print(f"It was verb its wings and breathing plural_noun  of fire")
                print(f"I was feeling very adjective2 and decided to  verb2")
                print(f"my sword and verb3 the dragon")



                adjective = input('Enter an adjective')
                noun = input('Enter a noun')
                verb = input('Enter a verb')
                plural_noun = input('Enter a plural noun')
                adjective2 = input('Enter another adjective')
                verb2 = input('Enter another verb')
                verb3 = input('Enter third verb')

                if adjective == 'majestic' and noun == 'castle' and verb == 'flapping' and plural_noun == 'embers' and adjective2 == 'brave' and verb2 == 'unsheathe' and verb3 == 'vanquish':
                    print('You unlocked a new artifact')
                    addToInventory('Mystic orb')
                    print('You use the mystic orb to lift the curse in narnia')
                    print('Narnia begins to heal. You are hailed as the hero')
                    print('Congratulations! You won the game')
                    break
                else:
                    print('Wrong input')

            elif choice == '2':
                print('Thanks for playing')
                break
            else:
                print('Invalid input')







#Create a list to hold items found in the game
inventory = []


# subroutine to add items to the inventory
def addToInventory(item):
    inventory.append(item)



def printInventory():
    if inventory:
        print('your inventory contains:')
        for item in inventory:
            print(item)

start_game()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\ '
# <>:3: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\USER\AppData\Local\Temp\ipykernel_12680\1783591583.py:3: SyntaxWarning: invalid escape sequence '\ '
#   print('''           _       _                 _                                __
#            _       _                 _                                __
#                / \   __| |_   _____ _ __ | |_ _   _ _ __ ___  ___    ___  / _|
#               / _ \ / _` \ \ / / _ \ '_ \| __| | | | '__/ _ \/ __|  / _ \| |_
#              / ___ \ (_| |\ V /  __/ | | | |_| |_| | | |  __/\__ \ | (_) |  _|
#             /_/  _\_\__,_| \_/ \___|_| |_|\__|\__,_|_|  \___||___/  \___/|_|
#             | \ | | __ _ _ __ _ __ (_) __ _
#             |  \| |/ _` | '__| '_ \| |/ _` |
#             | |\  | (_| | |  | | | | | (_| |
#             |_| \_|\__,_|_|  |_| |_|_|\__,_|
#  Welcome to the adventure of narnia!
# ...
